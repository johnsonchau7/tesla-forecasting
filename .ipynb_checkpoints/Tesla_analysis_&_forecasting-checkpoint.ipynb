# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Data Acquisition

# %%
tesla_raw_data = pd.read_csv('tesla_raw_data.csv', index_col = 'Date', parse_dates=True)

# %%
tesla_raw_data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-09-01  502.140015  502.489990  329.880005  429.010010  429.010010
# 2020-10-01  440.760010  465.899994  379.109985  388.040009  388.040009
# 2020-11-01  394.000000  607.799988  392.299988  567.599976  567.599976
# 2020-12-01  597.590027  695.000000  541.210022  695.000000  695.000000
# 2020-12-18  668.900024  695.000000  628.539978  695.000000  695.000000
#
#                 Volume
# Date
# 2020-09-01  1736563100
# 2020-10-01   833832100
# 2020-11-01   782494200
# 2020-12-01   879907900
# 2020-12-18   222126194

# %%
tesla_raw_data.index
# Out:
# DatetimeIndex(['2010-06-01', '2010-07-01', '2010-08-01', '2010-09-01',
#                '2010-10-01', '2010-11-01', '2010-12-01', '2011-01-01',
#                '2011-02-01', '2011-03-01',
#                ...
#                '2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01',
#                '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01',
#                '2020-12-01', '2020-12-18'],
#               dtype='datetime64[ns]', name='Date', length=128, freq=None)

# %% [markdown]
# # 2. Data Pre-processing

# %% [markdown]
# ### 2.1 Keep date and closing price

# %%
tesla_price = tesla_raw_data[['Close']].head(len(tesla_raw_data)-1)

# %%
tesla_price
# Out:
#                  Close
# Date
# 2010-06-01    4.766000
# 2010-07-01    3.988000
# 2010-08-01    3.896000
# 2010-09-01    4.082000
# 2010-10-01    4.368000
# ...                ...
# 2020-08-01  498.320007
# 2020-09-01  429.010010
# 2020-10-01  388.040009
# 2020-11-01  567.599976
# 2020-12-01  695.000000
#
# [127 rows x 1 columns]

# %% [markdown]
# ### 2.3 Check for null values

# %%
tesla_cleaned_data = tesla_price
tesla_cleaned_data.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %% [markdown]
# There is no null values in dataset

# %% [markdown]
# # 3. Exploratory Data Analysis

# %% [markdown]
# ### 3.1 Summary Statistics

# %%
def summary_stats(df):
    summary_statistics = []
    statistics_columns = ["Mean", "Median", "Standard Deviation", 
                          "Sample Variance","Kurtosis", 
                          "Skewness", "Range", "Minimum", 
                          "Maximum", "Sum", "Count"] # measures of statistics
    selected_cols = []
    for column in df:
        if df[column].dtype == np.float64 or df[column].dtype == np.int64: #checks if column is numerical type
            current = [] #list holding current statistics

            #measures key statistics of column
            current.append(df[column].mean())
            current.append(df[column].median())
            current.append(df[column].std())
            current.append(df[column].var())
            current.append(df[column].kurt())
            current.append(df[column].skew())
            current.append(df[column].max() - df[column].min())
            current.append(df[column].min())
            current.append(df[column].max())
            current.append(df[column].sum())
            current.append(df[column].count())

            summary_statistics.append(current)#append statistics of column to list
            selected_cols.append(column)

    statistics = pd.DataFrame()
    for i in range(len(summary_statistics)):
        statistics[selected_cols[i]] = summary_statistics[i]
    statistics.insert(0, "Measure of statistics", statistics_columns)
    statistics.set_index("Measure of statistics", inplace = True)
    return statistics

# %%
summary_stats(tesla_cleaned_data)
# Out:
#                               Close
# Measure of statistics
# Mean                      62.926110
# Median                    44.692001
# Standard Deviation       102.638185
# Sample Variance        10534.596922
# Kurtosis                  18.919223
# Skewness                   4.155832
# Range                    691.104000
# Minimum                    3.896000
# Maximum                  695.000000
# Sum                     7991.616032
# Count                    127.000000

# %% [markdown]
# ### 3.2 Time Series plot

# %%
def stationarity_plot(df, order="", transformation=""):
    rolmean = df.rolling(window=12).mean()
    rolstd = df.rolling(window=12).std()
    fig, ax= plt.subplots(figsize=(15,5))
    plt.plot(df['Close'], label='Original')
    plt.plot(rolmean, label='Rolling 12 month average')
    plt.plot(rolstd, label='Rolling 12 month STDEV')
    plt.legend(loc='best')
    ax.set_xlabel('Time')
    ax.set_ylabel('Price')
    ax.set_title('Tesla stock price {} {}'.format(order, transformation))
    plt.show()

# %%
fig, ax= plt.subplots(figsize=(15,5))
tesla_cleaned_data['Close'].plot()
ax.set_xlabel('Time')
ax.set_ylabel('Price')
ax.set_title('Tesla stock price')
ax.set_xticks([], minor=True)
plt.show()

# %% [markdown]
# Tesla's stock price exhibit positive trend with huge growth in 2020.

# %%
fig, ax= plt.subplots(figsize=(15,5))
(tesla_cleaned_data['Close'].pct_change()*100).plot()
ax.set_xlabel('Time')
ax.set_ylabel('Daily change in price (Percentage)')
ax.set_title('Tesla stock price percentage change')
plt.show()

# %% [markdown]
# Tesla's stock price have been more volatile in 2020.

# %%
tesla_cleaned_data['Close']
# Out:
# Date
# 2010-06-01      4.766000
# 2010-07-01      3.988000
# 2010-08-01      3.896000
# 2010-09-01      4.082000
# 2010-10-01      4.368000
#                  ...
# 2020-08-01    498.320007
# 2020-09-01    429.010010
# 2020-10-01    388.040009
# 2020-11-01    567.599976
# 2020-12-01    695.000000
# Name: Close, Length: 127, dtype: float64

# %%
stationarity_plot(tesla_cleaned_data)

# %% [markdown]
# Rolling average is not constant, however, variance is relatively constant, except for 2020 period. Thus, feature engineering is required to make data stationary.

# %% [markdown]
# ### 3.3 Time Series Decomposition

# %% [markdown]
# #### 3.3.1 Additive

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(tesla_cleaned_data['Close'], model='additive', period=12)
plt.rcParams['figure.figsize'] = [15, 8]
result.plot()
plt.show()

# %% [markdown]
# #### 3.3.2 Multiplicative

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(tesla_cleaned_data['Close'], model='multiplicative', period=12)
plt.rcParams['figure.figsize'] = [15, 8]
result.plot()
plt.show()

# %% [markdown]
# Multiplicative is able to capture variance of time series better, as seen in latter part of 2020 residuals. For additive, errors varies with time more, thus, multiplicative will capture time series decomposition better.
#
# Seasonality is prevalent in data, where its impact is lowest in beginning of year and peaks in mid year.

# %% [markdown]
# ### 3.4 Hypothesis Testing for stationarity

# %% [markdown]
# #### 3.4.1 ADF test

# %%
result = adfuller(tesla_cleaned_data['Close'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: 1.247302
# p-value: 0.996297

# %% [markdown]
# Since p_value > 0.05, we do not reject null hypothesis. Thus, there is a unit root.

# %% [markdown]
# #### 3.4.2 KPSS test

# %%
statistic, p_value, n_lags, critical_values = kpss(tesla_cleaned_data['Close'])
# Format Output
print(f'KPSS Statistic: {statistic}')
print(f'p-value: {p_value}')
# Out:
# KPSS Statistic: 0.6236126689428586
# p-value: 0.020489757368831032

# %% [markdown]
# Since p_value < 0.05, we reject null hypothesis. Thus, data is not stationary.

# %% [markdown]
# ### 3.5 Autocorrelation and partial auto correlation

# %%
def acf_pacf_plot(df, order="", transformation=""):
    plt.rcParams['figure.figsize'] = [15, 4]
    auto_title = "Autocorrelation {} {}".format(order, transformation)
    plot_acf(df.dropna(), title=auto_title)
    plt.show()
    
    pauto_title = "Partial Autocorrelation {} {}".format(order, transformation)
    plot_pacf(df.dropna(), title=pauto_title)
    plt.show()

# %%
acf_pacf_plot(tesla_cleaned_data)

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ### 4.1 Log Transformation

# %%
tesla_cleaned_data_log = np.log(tesla_cleaned_data)

# %%
tesla_cleaned_data_log.tail()
# Out:
#                Close
# Date
# 2020-08-01  6.211242
# 2020-09-01  6.061480
# 2020-10-01  5.961108
# 2020-11-01  6.341417
# 2020-12-01  6.543912

# %%
tesla_cleaned_data.tail()
# Out:
#                  Close
# Date
# 2020-08-01  498.320007
# 2020-09-01  429.010010
# 2020-10-01  388.040009
# 2020-11-01  567.599976
# 2020-12-01  695.000000

# %% [markdown]
# ### 4.2 Differencing

# %%
def first_order_differencing(df):
    first_order_df = df.diff()
    return first_order_df

# %%
def second_order_differencing(df):
    second_order_df = df.diff(2)
    return second_order_df

# %% [markdown]
# #### 4.2.1 Differencing for Original Data

# %%
tesla_cleaned_data_first_order = first_order_differencing(tesla_cleaned_data)
tesla_cleaned_data_second_order = second_order_differencing(tesla_cleaned_data)

# %%
tesla_cleaned_data_first_order.head()
# Out:
#             Close
# Date
# 2010-06-01    NaN
# 2010-07-01 -0.778
# 2010-08-01 -0.092
# 2010-09-01  0.186
# 2010-10-01  0.286

# %%
tesla_cleaned_data_second_order.head()
# Out:
#             Close
# Date
# 2010-06-01    NaN
# 2010-07-01    NaN
# 2010-08-01 -0.870
# 2010-09-01  0.094
# 2010-10-01  0.472

# %% [markdown]
# #### 4.2.2 Differencing for Log Transformed Data

# %%
tesla_cleaned_data_log_first_order = first_order_differencing(tesla_cleaned_data_log)
tesla_cleaned_data_log_second_order = second_order_differencing(tesla_cleaned_data_log)

# %%
tesla_cleaned_data_log_first_order.head()
# Out:
#                Close
# Date
# 2010-06-01       NaN
# 2010-07-01 -0.178218
# 2010-08-01 -0.023339
# 2010-09-01  0.046637
# 2010-10-01  0.067718

# %%
tesla_cleaned_data_log_second_order.head()
# Out:
#                Close
# Date
# 2010-06-01       NaN
# 2010-07-01       NaN
# 2010-08-01 -0.201557
# 2010-09-01  0.023297
# 2010-10-01  0.114355

# %% [markdown]
# ### 4.3 Stationarity Comparison

# %%
stationarity_plot(tesla_cleaned_data_first_order, "(1st order diff)", "(normal)")
# stationarity_plot(tesla_cleaned_data_second_order, "(2nd order diff)", "(normal)")
stationarity_plot(tesla_cleaned_data_log_first_order, "(1st order diff)", "(log)")
# stationarity_plot(tesla_cleaned_data_log_second_order, "(2nd order diff)", "(log)")

# %% [markdown]
# Log transformation with 1st order difference exhibits the most stationarity attributes out of all transformation.

# %% [markdown]
# ### 4.4 Autocorrelation and Partial Autocorrelation

# %%
acf_pacf_plot(tesla_cleaned_data_first_order, "(1st order diff)", "(normal)")

# %%
# acf_pacf_plot(tesla_cleaned_data_second_order, "(2nd order diff)", "(normal)")

# %%
acf_pacf_plot(tesla_cleaned_data_log_first_order, "(1st order diff)", "(log)")

# %%
# acf_pacf_plot(tesla_cleaned_data_log_second_order, "(2nd order diff)", "(log)")

# %% [markdown]
# Log transformation with 1st order difference exhibits autocorrelation and partial autocorrelation that aligns with theory.

# %% [markdown]
# # 5. Forecasting

# %% [markdown]
# ### 5.1 Split into training and validation set

# %%
def split_training_validation(df, training_pct=0.8):
    y = df['Close'].dropna()
    training_size = int(len(y)*training_pct)
    validation_size = len(y) - training_size
    train = y.iloc[0:training_size]
    validation = y.iloc[training_size:]
    return y, train, validation

# %%
def training_validation_plot(train, validation, transformation=""):
    fig, ax= plt.subplots(figsize=(15,5))
    train.plot(label='Training')
    validation.plot(label='Validation')
    ax.set_xlabel('Time')
    ax.set_ylabel('Price')
    ax.set_title('Tesla stock price {}'.format(transformation))
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #### 5.1.1 Split for Original Data

# %%
y, train, validation = split_training_validation(tesla_cleaned_data, training_pct=0.8)

# %%
train.tail()
# Out:
# Date
# 2018-06-01    68.589996
# 2018-07-01    59.627998
# 2018-08-01    60.332001
# 2018-09-01    52.953999
# 2018-10-01    67.463997
# Name: Close, dtype: float64

# %%
validation.tail()
# Out:
# Date
# 2020-08-01    498.320007
# 2020-09-01    429.010010
# 2020-10-01    388.040009
# 2020-11-01    567.599976
# 2020-12-01    695.000000
# Name: Close, dtype: float64

# %%
training_validation_plot(train, validation, "(original)")

# %%
y_log, train_log, validation_log = split_training_validation(tesla_cleaned_data_log, training_pct=0.8)

# %%
train_log.tail()
# Out:
# Date
# 2018-06-01    4.228147
# 2018-07-01    4.088125
# 2018-08-01    4.099863
# 2018-09-01    3.969424
# 2018-10-01    4.211594
# Name: Close, dtype: float64

# %%
validation_log.tail()
# Out:
# Date
# 2020-08-01    6.211242
# 2020-09-01    6.061480
# 2020-10-01    5.961108
# 2020-11-01    6.341417
# 2020-12-01    6.543912
# Name: Close, dtype: float64

# %%
training_validation_plot(train_log, validation_log, "(log)")

# %% [markdown]
# #### 5.1.2 Split difference data

# %%
y_diff, train_diff, validation_diff = split_training_validation(tesla_cleaned_data_first_order, training_pct=0.8)

# %%
y_diff
# Out:
# Date
# 2010-07-01     -0.778000
# 2010-08-01     -0.092000
# 2010-09-01      0.186000
# 2010-10-01      0.286000
# 2010-11-01      2.698000
#                  ...
# 2020-08-01    212.167999
# 2020-09-01    -69.309997
# 2020-10-01    -40.970001
# 2020-11-01    179.559967
# 2020-12-01    127.400024
# Name: Close, Length: 126, dtype: float64

# %%
y_log_diff, train_log_diff, validation_log_diff = split_training_validation(tesla_cleaned_data_log_first_order, 
                                                                            training_pct=0.8)

# %%
y_log_diff
# Out:
# Date
# 2010-07-01   -0.178218
# 2010-08-01   -0.023339
# 2010-09-01    0.046637
# 2010-10-01    0.067718
# 2010-11-01    0.480989
#                 ...
# 2020-08-01    0.554719
# 2020-09-01   -0.149762
# 2020-10-01   -0.100372
# 2020-11-01    0.380308
# 2020-12-01    0.202495
# Name: Close, Length: 126, dtype: float64

# %% [markdown]
# ### 5.2 Arima

# %% [markdown]
# #### 5.2.1 Forecast Original Observation

# %%
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# %%
def arima_cross_validation(y, train, validation, configs):
    start = y.index.get_loc(validation.index[0])
    
    arima_preds = {}
    for config in configs:
        model = ARIMA(train, order=config)
        fitted_model = model.fit(disp=-1)
        output = fitted_model.forecast(steps=len(validation))
        y_hat = output[0]
        arima_preds[config] = y_hat
        
    return arima_preds

# %%
def inverse_difference_predictions(train, predictions_diff, interval):
    history = [x for x in train]
    # invert the differenced forecast to something usable
    inversed_predictions = {}
    for key in predictions_diff:
        inversed_prediction = []
        
        for yhat in predictions_diff[key]:
            inverted = inverse_difference(history, yhat, interval)
            history.append(inverted)
            inversed_prediction.append(inverted)
        
        inversed_predictions[key] = inversed_prediction
    return inversed_predictions

# %%
configs = [(3,1,2), (3,1,3)]
arima_predictions_diff = arima_cross_validation(y_diff, train_diff, validation_diff, configs)

# %%
arima_predictions_diff
# Out:
# {(3,
#   1,
#   2): array([-3.12937793,  3.66343608, -4.86077231,  5.07410185, -2.81516139,
#          3.8991576 , -2.58381314,  3.33776499, -1.89810158,  2.85478728,
#         -1.48347009,  2.43735431, -1.1042881 ,  2.10874429, -0.80174036,
#          1.833817  , -0.5518969 ,  1.610409  , -0.34681224,  1.42680111,
#         -0.17846522,  1.27654895, -0.04011199,  1.15347874,  0.07356341,
#          1.05274278]),
#  (3,
#   1,
#   3): array([-3.11281175,  3.7707008 , -4.97211973,  5.08331463, -2.96611506,
#          4.12667132, -2.77943726,  3.54279547, -2.14578664,  3.10371489,
#         -1.73426377,  2.69051812, -1.36399047,  2.36111496, -1.05461618,
#          2.07844797, -0.79480535,  1.84221322, -0.57546779,  1.64334057,
#         -0.39094363,  1.47620608, -0.23542759,  1.33576152, -0.10440472,
#          1.21775942])}

# %%
arima_predictions = inverse_difference_predictions(train_diff, arima_predictions_diff, 1)

# %%
fig, ax= plt.subplots(figsize=(15,5))
train.plot(label='Training')
validation.plot(label='Validation')
for key in arima_predictions:
    pd.Series(arima_predictions[key], index=validation.index).plot(label="ARIMA normal: {}".format(key))
ax.set_xlabel('Time')
ax.set_ylabel('Price')
ax.set_title('Tesla Stock Price')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### 5.2.2 Forecast Log Observation¶

# %%
configs = [(3,1,2), (3,1,3)]
arima_predictions_log_diff = arima_cross_validation(y_log_diff, train_log_diff, validation_log_diff, configs)

# %%
arima_predictions_log_diff
# Out:
# {(3,
#   1,
#   2): array([ 5.05313978e-03,  4.28208560e-02, -4.99310393e-02,  4.34465665e-02,
#         -1.68373742e-02,  3.41898836e-02, -1.21729044e-02,  2.45395129e-02,
#         -6.13489999e-03,  1.92066757e-02, -2.35834658e-03,  1.49573571e-02,
#          6.37330888e-06,  1.19070907e-02,  1.49175849e-03,  9.61541207e-03,
#          2.32940892e-03,  7.85117406e-03,  2.72933122e-03,  6.45324080e-03,
#          2.82540414e-03,  5.30745744e-03,  2.71168716e-03,  4.33604239e-03,
#          2.45310905e-03,  3.48503159e-03]),
#  (3,
#   1,
#   3): array([ 0.0045595 ,  0.04033024, -0.04797741,  0.0451486 , -0.01350361,
#          0.02999725, -0.00882266,  0.02153016, -0.00233075,  0.01623621,
#          0.00081273,  0.01251395,  0.00272152,  0.01000462,  0.00369667,
#          0.00819334,  0.00410401,  0.00684087,  0.00415039,  0.00577433,
#          0.00396851,  0.00488934,  0.00364253,  0.00411893,  0.00322541,
#          0.00342095])}

# %%
arima_log_predictions = inverse_difference_predictions(train_log_diff, arima_predictions_log_diff, 1)
arima_exp_predictions = {}
for key in arima_log_predictions:
    arima_exp_predictions[key] = np.exp(arima_log_predictions[key])
    
arima_exp_predictions
# Out:
# {(3,
#   1,
#   2): array([1.28046542, 1.33648693, 1.27139337, 1.32784856, 1.30567824,
#         1.35109114, 1.33474413, 1.36790329, 1.35953703, 1.3859016 ,
#         1.38263701, 1.40347305, 1.40348199, 1.42029327, 1.42241358,
#         1.43615664, 1.43950594, 1.45085223, 1.4548175 , 1.46423614,
#         1.46837905, 1.47619313, 1.48020153, 1.48663369, 1.49028504,
#         1.49548779]),
#  (3,
#   1,
#   3): array([1.50232203, 1.56414942, 1.49087734, 1.55973098, 1.53881055,
#         1.58566994, 1.57174165, 1.60594842, 1.60220971, 1.62843585,
#         1.62975988, 1.65028275, 1.65478015, 1.67141869, 1.67760881,
#         1.69141049, 1.69836631, 1.71002444, 1.71713646, 1.72708046,
#         1.73394802, 1.74244664, 1.74880513, 1.75602318, 1.76169622,
#         1.76773321])}

# %%
fig, ax= plt.subplots(figsize=(15,5))
train.plot(label='Training')
validation.plot(label='Validation')
for key in arima_exp_predictions:
    pd.Series(arima_exp_predictions[key], index=validation.index).plot(label="ARIMA normal: {}".format(key))
ax.set_xlabel('Time')
ax.set_ylabel('Price')
ax.set_title('Tesla Stock Price')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### 5.2.3 Model Validation

# %%
def model_performance_metrics(fitted, actual, train, name):
    table = pd.DataFrame()
    
    #rmse and se
    y = np.array((np.ravel(actual)-np.ravel(fitted))**2)
    y_sum = np.sum(y)
    n = len(y)

    resample = np.sqrt((y_sum-y)/(n-1))

    rmse = np.sqrt(y_sum/n)
    se = np.sqrt((n-1)*np.var(resample))
    
    #mape
    y_true = np.array(actual)
    y_pred = np.array(fitted)
    percentage = np.abs((y_true - y_pred) / y_true) * 100
    mape = np.mean(percentage)
    
    #MASE
    d = np.abs(np.diff(train)).sum()/(n-1)
    
    errors = np.abs(actual - fitted)
    mase = errors.mean()/d
    
    table['MASE'] = [mase]
    table['MAPE'] = [mape]
    table['RMSE'] = [rmse]
    table['SE'] = [se]
    table.index = [name]
    return table.round(4)

# %%
model_1_perf = model_performance_metrics(arima_predictions[(3,1,2)], validation, train, "Model 1")
model_2_perf = model_performance_metrics(arima_predictions[(3,1,3)], validation, train, "Model 2")
model_3_perf = model_performance_metrics(arima_exp_predictions[(3,1,2)], validation_log, train_log, "Model 3")
model_4_perf = model_performance_metrics(arima_exp_predictions[(3,1,3)], validation_log, train_log, "Model 4")

# %%
model_results = pd.concat([model_1_perf, model_2_perf, model_3_perf, model_4_perf])
model_results
# Out:
#             MASE     MAPE      RMSE       SE
# Model 1  11.5095  80.0165  237.3629  48.0336
# Model 2  10.6296  65.6487  229.6196  47.8812
# Model 3   7.6372  69.5759    3.4334   0.1776
# Model 4   7.0645  64.1757    3.1885   0.1753

# %% [markdown]
# #### 5.2.4 Model Diagnostic

# %%
def forecast_model_diagnostic(resid):
    #residual plot
    fig, ax= plt.subplots(figsize=(8,5))
    resid.plot()
    ax.set_xlabel('')
    ax.set_xticks([], minor=True) 
    ax.set_title('Residual plot')
    sns.despine()
    plt.show()
    
    #autocorrelation plot
    fig, ax = plt.subplots(figsize=(8,5))
    sm.graphics.tsa.plot_acf(resid, lags=10, ax=ax)
    sns.despine()
    plt.show()
    
    #residual distribution plot
    fig, ax= plt.subplots(figsize=(8,5))
    sns.distplot(resid)
    ax.set_title('Residual distribution plot')
    ax.set_ylabel('Density')
    ax.set_xlabel('Residual')
    plt.show()

# %%
resid_arima = validation - arima_exp_predictions[(3,1,3)]
forecast_model_diagnostic(resid_arima)

# %% [markdown]
# #### 5.2.5 Forecast Next 24 Months

# %%
model = ARIMA(y_log_diff, order=(3,1,3))
fitted_model = model.fit(disp=-1)
output = fitted_model.forecast(steps=24)
y_hat_final = output[0]
y_hat_final
# Out:
# array([0.1313334 , 0.17699138, 0.13030959, 0.14450376, 0.17360781,
#        0.13835569, 0.14916396, 0.17239285, 0.14529865, 0.15363822,
#        0.17221607, 0.15145773, 0.15794888, 0.17285216, 0.1570131 ,
#        0.16212277, 0.17412404, 0.16210374, 0.16618288, 0.17589312,
#        0.16683672, 0.17014874, 0.17805094, 0.17129454])

# %%
arima_predictions_log_diff_final = {(3,1,3): y_hat_final}
arima_log_predictions_final = inverse_difference_predictions(y_log_diff, arima_predictions_log_diff_final, 1)
arima_exp_predictions_final = {}
for key in arima_log_predictions_final:
    arima_exp_predictions_final[key] = np.exp(arima_log_predictions_final[key])
    
arima_exp_predictions_final
# Out:
# {(3,
#   1,
#   3): array([ 1.39630344,  1.66665685,  1.89862382,  2.19379536,  2.60971466,
#          2.99695444,  3.47905444,  4.13361943,  4.78005499,  5.57387372,
#          6.62139681,  7.70418797,  9.02242325, 10.7248675 , 12.54821236,
#         14.75675552, 17.56353746, 20.65440802, 24.38849823, 29.07866535,
#         34.35822644, 40.73103038, 48.66894572, 57.76226467])}

# %%
forecast__arima_index = pd.date_range(start='1/1/2021', periods=24, freq='MS')
forecast_arima_24 = pd.Series(arima_exp_predictions_final[(3,1,3)], index=forecast__arima_index)
pd.DataFrame(forecast_arima_24)
# len(arima_exp_predictions_final[(3,1,3)])
# Out:
#                     0
# 2021-01-01   1.396303
# 2021-02-01   1.666657
# 2021-03-01   1.898624
# 2021-04-01   2.193795
# 2021-05-01   2.609715
# 2021-06-01   2.996954
# 2021-07-01   3.479054
# 2021-08-01   4.133619
# 2021-09-01   4.780055
# 2021-10-01   5.573874
# 2021-11-01   6.621397
# 2021-12-01   7.704188
# 2022-01-01   9.022423
# 2022-02-01  10.724867
# 2022-03-01  12.548212
# 2022-04-01  14.756756
# 2022-05-01  17.563537
# 2022-06-01  20.654408
# 2022-07-01  24.388498
# 2022-08-01  29.078665
# 2022-09-01  34.358226
# 2022-10-01  40.731030
# 2022-11-01  48.668946
# 2022-12-01  57.762265

# %%
fig, ax= plt.subplots(figsize=(15,5))
y.plot(label='Historic')
forecast_arima_24.plot(label="Forecast")
ax.set_xlabel('Time')
ax.set_ylabel('Price')
ax.set_title('Tesla Stock Price')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Holt
